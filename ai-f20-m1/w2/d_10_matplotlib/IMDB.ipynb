# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

from time import sleep
from random import randint

def remove_html_tags(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<.*?>')
    clean = re.sub(clean, '', text)
    clean = clean.split(",")
    return clean


imdb_url = "https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating"
page = requests.get(imdb_url) # requesting the webpage from the internet
soup = BeautifulSoup(page.text, 'html.parser')

bigBoxes = soup.find_all("div",  class_ = "lister-item mode-advanced")
#print(bigBoxes)

Films = {"Name":[], "Description":[], "Duration": [],"Date of Release":[], "Genre":[],"Rating":[],"Director":[],"Actors":[],"Link":[]}

for box in bigBoxes:
    link_string = "https://www.imdb.com" + box.a['href'] 
    #print(link_string)
    page = requests.get(link_string) # requesting the webpage from the internet
    soup = BeautifulSoup(page.text, 'html.parser')
    filmBox = soup.find_all('div', class_="heroic-overview")
    #print(filmBox)
    for film in filmBox:
        #print("here")
        name = film.find('h1', class_='')
        if name is None: 
            #print("LONG")
            name = film.find('h1', class_="long")

        description = film.find('div', class_="plot_summary").text
        description = description.replace("                    ","")
        description = description.split("Director:", 1)[0]
        description = description.replace("\n","")
        
        multi_info = film.find('div', class_="subtext").text.replace(" ","").replace("\n","")
        multi_info = multi_info.split('|') #Duration, Genre, Realese Date
        multi_info.pop(0)
        #print("GENERI" + multi_info[1])
        multi_info[1] = multi_info[1].replace(",", ", ")
        multi_info[0] = multi_info[0].replace("h", "h ")

        

        Rating = film.find('span', itemprop="ratingValue").text
        
        Director = " "
        Stars = []
        for a in film.find_all('div', class_="credit_summary_item"):
            if a.find('h4', class_="inline").text == "Director:":
                Director = a.find('a', href=True).text
            if a.find('h4', class_="inline").text == "Directors:":
                Director = remove_html_tags(str(a.find_all('a', href=True)))
            if a.find('h4', class_="inline").text == "Stars:":
                Stars = remove_html_tags(str(a.find_all('a', href=True)))
                Stars[0] = Stars[0].replace("[","")
                Stars.pop(3)
#Films = {"Name":[], "Description":[], "Date of Release":[], "C":[], "Release Date":[],"Rating":[],"Director":[],"Actors":[],"Link":[]}
  
        Films["Name"].append(name.text)
        Films["Description"].append(description)
        Films["Date of Release"] .append(multi_info[2])
        Films["Duration"] .append(multi_info[0])
        Films["Genre"] .append(multi_info[1])
        Films["Rating"].append(Rating)
        Films["Director"].append(Director)
        Films["Actors"].append(Stars)
        Films["Link"].append(link_string)


#print(Films)

dF = pd.DataFrame(Films, index=Films["Name"])
print(dF)
# Out:
#                                                                                         Name  \
# The Shawshank Redemption (1994)                             The Shawshank Redemption (1994)
# The Godfather (1972)                                                   The Godfather (1972)
# The Dark Knight (2008)                                               The Dark Knight (2008)
# The Godfather: Part II (1974)                                 The Godfather: Part II (1974)
# 12 Angry Men (1957)                                                     12 Angry Men (1957)
# ...                                                                                      ...
# Eternal Sunshine of the Spotless Mind (2004)   Eternal Sunshine of the Spotless Mind (2004)
# Amélie (2001)                                                                 Amélie (2001)
# Snatch (2000)                                                                 Snatch (2000)
# Requiem for a Dream (2000)                                       Requiem for a Dream (2000)
# American Beauty (1999)                                               American Beauty (1999)
#
#                                                                                      Description  \
# The Shawshank Redemption (1994)                Two imprisoned men bond over a number of years...
# The Godfather (1972)                           The aging patriarch of an organized crime dyna...
# The Dark Knight (2008)                         When the menace known as the Joker wreaks havo...
# The Godfather: Part II (1974)                  The early life and career of Vito Corleone in ...
# 12 Angry Men (1957)                            A jury holdout attempts to prevent a miscarria...
# ...                                                                                          ...
# Eternal Sunshine of the Spotless Mind (2004)   When their relationship turns sour, a couple u...
# Amélie (2001)                                  Amélie is an innocent and naive girl in Paris ...
# Snatch (2000)                                  Unscrupulous boxing promoters, violent bookmak...
# Requiem for a Dream (2000)                     The drug-induced utopias of four Coney Island ...
# American Beauty (1999)                         A sexually frustrated suburban father has a mi...
#
#                                                Duration     Date of Release  \
# The Shawshank Redemption (1994)                2h 22min  17February1995(UK)
# The Godfather (1972)                           2h 55min    24August1972(UK)
# The Dark Knight (2008)                         2h 32min      24July2008(UK)
# The Godfather: Part II (1974)                  3h 22min       15May1975(UK)
# 12 Angry Men (1957)                            1h 36min    10April1957(USA)
# ...                                                 ...                 ...
# Eternal Sunshine of the Spotless Mind (2004)   1h 48min     30April2004(UK)
# Amélie (2001)                                   2h 2min    5October2001(UK)
# Snatch (2000)                                  1h 44min  1September2000(UK)
# Requiem for a Dream (2000)                     1h 42min   19January2001(UK)
# American Beauty (1999)                          2h 2min   4February2000(UK)
#
#                                                                 Genre Rating  \
# The Shawshank Redemption (1994)                                 Drama    9.3
# The Godfather (1972)                                     Crime, Drama    9.2
# The Dark Knight (2008)                           Action, Crime, Drama    9.0
# The Godfather: Part II (1974)                            Crime, Drama    9.0
# 12 Angry Men (1957)                                      Crime, Drama    9.0
# ...                                                               ...    ...
# Eternal Sunshine of the Spotless Mind (2004)   Drama, Romance, Sci-Fi    8.3
# Amélie (2001)                                         Comedy, Romance    8.3
# Snatch (2000)                                           Comedy, Crime    8.3
# Requiem for a Dream (2000)                                      Drama    8.3
# American Beauty (1999)                                          Drama    8.3
#
#                                                            Director  \
# The Shawshank Redemption (1994)                      Frank Darabont
# The Godfather (1972)                           Francis Ford Coppola
# The Dark Knight (2008)                            Christopher Nolan
# The Godfather: Part II (1974)                  Francis Ford Coppola
# 12 Angry Men (1957)                                    Sidney Lumet
# ...                                                             ...
# Eternal Sunshine of the Spotless Mind (2004)          Michel Gondry
# Amélie (2001)                                    Jean-Pierre Jeunet
# Snatch (2000)                                           Guy Ritchie
# Requiem for a Dream (2000)                         Darren Aronofsky
# American Beauty (1999)                                   Sam Mendes
#
#                                                                                          Actors  \
# The Shawshank Redemption (1994)                     [Tim Robbins,  Morgan Freeman,  Bob Gunton]
# The Godfather (1972)                                   [Marlon Brando,  Al Pacino,  James Caan]
# The Dark Knight (2008)                          [Christian Bale,  Heath Ledger,  Aaron Eckhart]
# The Godfather: Part II (1974)                      [Al Pacino,  Robert De Niro,  Robert Duvall]
# 12 Angry Men (1957)                                 [Henry Fonda,  Lee J. Cobb,  Martin Balsam]
# ...                                                                                         ...
# Eternal Sunshine of the Spotless Mind (2004)        [Jim Carrey,  Kate Winslet,  Tom Wilkinson]
# Amélie (2001)                                       [Audrey Tautou,  Mathieu Kassovitz,  Rufus]
# Snatch (2000)                                    [Jason Statham,  Brad Pitt,  Benicio Del Toro]
# Requiem for a Dream (2000)                     [Ellen Burstyn,  Jared Leto,  Jennifer Connelly]
# American Beauty (1999)                            [Kevin Spacey,  Annette Bening,  Thora Birch]
#
#                                                                                 Link
# The Shawshank Redemption (1994)                https://www.imdb.com/title/tt0111161/
# The Godfather (1972)                           https://www.imdb.com/title/tt0068646/
# The Dark Knight (2008)                         https://www.imdb.com/title/tt0468569/
# The Godfather: Part II (1974)                  https://www.imdb.com/title/tt0071562/
# 12 Angry Men (1957)                            https://www.imdb.com/title/tt0050083/
# ...                                                                              ...
# Eternal Sunshine of the Spotless Mind (2004)   https://www.imdb.com/title/tt0338013/
# Amélie (2001)                                  https://www.imdb.com/title/tt0211915/
# Snatch (2000)                                  https://www.imdb.com/title/tt0208092/
# Requiem for a Dream (2000)                     https://www.imdb.com/title/tt0180093/
# American Beauty (1999)                         https://www.imdb.com/title/tt0169547/
#
# [100 rows x 9 columns]
